# %%
import folium
mymap = folium.Map(location = [52.155499, 5.387740], 
                   width = 950, 
                   height = 550,
                   zoom_start = 12, 
                   tiles = 'openstreetmap')
folium.TileLayer('Stamen Terrain').add_to(mymap)
folium.TileLayer('Stamen Toner').add_to(mymap)
folium.TileLayer('Stamen Water Color').add_to(mymap)
folium.TileLayer('cartodbpositron').add_to(mymap)
folium.TileLayer('cartodbdark_matter').add_to(mymap)
folium.LayerControl().add_to(mymap)
import pandas as pd
df = pd.read_csv('Data/stations_NL.csv',sep=",")
display(df)
for lat, lng, name in zip(df['latitude'], df['longitude'], df['name']):    
    # station = folium.CircleMarker(
    #         location=[lat, lng],
    #         radius=8,
    #         color='red',
    #         fill=True,
    #         fill_color='yellow',
    #         fill_opacity=0.5)   
    # station.add_to(mymap)
    
    station_name = folium.Marker(
            location=[lat, lng],
            popup = name,            
        )   
    station_name.add_to(mymap)
mymap
# Out:
#       id                  name                  slug        uic   uic8_sncf  \
# 0   8607               Alkmaar               alkmaar  8400050.0         NaN
# 1   8608                Almelo                almelo  8400051.0         NaN
# 2   8609  Amsterdam Sloterdijk  amsterdam-sloterdijk  8400059.0         NaN
# 3   8610             Apeldoorn             apeldoorn  8400066.0         NaN
# 4   8615                 Delft                 delft  8400170.0         NaN
# 5   8616              Deventer              deventer  8484173.0         NaN
# 6   8619                 Gouda                 gouda  8400258.0         NaN
# 7   8620             Groningen             groningen  8400263.0         NaN
# 8   8621            Den Helder            den-helder  8400311.0         NaN
# 9   8624             Hilversum             hilversum  8400322.0         NaN
# 10  8626             Hoofddorp             hoofddorp  8400332.0         NaN
# 11  8627       Leiden Centraal       leiden-centraal  8400390.0         NaN
# 12  8630      Bad Nieuweschans      bad-nieuweschans  8400457.0         NaN
# 13  8631              Nijmegen              nijmegen  8400470.0         NaN
# 14  8632             Oldenzaal             oldenzaal  8484483.0         NaN
# 15  8635               Sittard               sittard  8400564.0         NaN
# 16  8636               Tilburg               tilburg  8400597.0         NaN
# 17  8637                 Venlo                 venlo  8400644.0         NaN
# 18  8640                 Weesp                 weesp  8400685.0         NaN
# 19  8641            Winschoten            winschoten  8400696.0         NaN
# 20  8643      Amsterdam Amstel      amsterdam-amstel  8400057.0         NaN
# 21  8644           Den Haag HS           den-haag-hs  8400280.0         NaN
# 22  8645                Zwolle                zwolle  8400747.0         NaN
# 23  8648            Leeuwarden            leeuwarden  8484387.0         NaN
# 24  8651              Enschede              enschede  8484212.0         NaN
# 25  8653                 Assen                 assen  8400073.0         NaN
# 26  8657             Amsterdam             amsterdam        NaN         NaN
# 27  8658            Amersfoort            amersfoort  8400055.0         NaN
# 28  8659                Arnhem                arnhem  8400071.0         NaN
# 29  8661                 Breda                 breda  8400131.0         NaN
# 30  8662             Dordrecht             dordrecht  8400180.0         NaN
# 31  8663              Den Haag              den-haag        NaN         NaN
# 32  8664     Den Haag Centraal     den-haag-centraal  8400282.0         NaN
# 33  8666             Eindhoven             eindhoven  8400206.0         NaN
# 34  8667               Haarlem               haarlem  8400285.0         NaN
# 35  8668            Maastricht            maastricht  8400424.0         NaN
# 36  8669            Roosendaal            roosendaal  8400526.0         NaN
# 37  8670    Rotterdam Centraal    rotterdam-centraal  8400530.0  84005306.0
# 38  8672      Schiphol Airport      schiphol-airport  8400561.0         NaN
# 39  8673      Utrecht Centraal      utrecht-centraal  8400621.0         NaN
#
#      latitude  longitude  parent_station_id country         time_zone  ...  \
# 0   52.637954   4.738474                NaN      NL  Europe/Amsterdam  ...
# 1   52.356735   6.655676                NaN      NL  Europe/Amsterdam  ...
# 2   52.389025   4.838111             8657.0      NL  Europe/Amsterdam  ...
# 3   52.209420   5.967480                NaN      NL  Europe/Amsterdam  ...
# 4   52.011424   4.353089                NaN      NL  Europe/Amsterdam  ...
# 5   52.257611   6.160109                NaN      NL  Europe/Amsterdam  ...
# 6   52.017626   4.702904                NaN      NL  Europe/Amsterdam  ...
# 7   53.212580   6.564121                NaN      NL  Europe/Amsterdam  ...
# 8   52.954572   4.760480                NaN      NL  Europe/Amsterdam  ...
# 9   52.226347   5.180195                NaN      NL  Europe/Amsterdam  ...
# 10  52.295006   4.702374                NaN      NL  Europe/Amsterdam  ...
# 11  52.175072   4.492997            32272.0      NL  Europe/Amsterdam  ...
# 12  53.184656   7.200222                NaN      NL  Europe/Amsterdam  ...
# 13  51.841824   5.851707                NaN      NL  Europe/Amsterdam  ...
# 14  52.306279   6.933137                NaN      NL  Europe/Amsterdam  ...
# 15  51.001603   5.858512                NaN      NL  Europe/Amsterdam  ...
# 16  51.560938   5.081116                NaN      NL  Europe/Amsterdam  ...
# 17  51.364407   6.171840                NaN      NL  Europe/Amsterdam  ...
# 18  52.312850   5.038525                NaN      NL  Europe/Amsterdam  ...
# 19  53.139237   7.034886                NaN      NL  Europe/Amsterdam  ...
# 20  52.346389   4.917778             8657.0      NL  Europe/Amsterdam  ...
# 21  52.069584   4.322669             8663.0      NL  Europe/Amsterdam  ...
# 22  52.506379   6.089841                NaN      NL  Europe/Amsterdam  ...
# 23  53.196220   5.791686                NaN      NL  Europe/Amsterdam  ...
# 24  52.222562   6.890222                NaN      NL  Europe/Amsterdam  ...
# 25  52.991599   6.567815                NaN      NL  Europe/Amsterdam  ...
# 26  52.378638   4.900825                NaN      NL  Europe/Amsterdam  ...
# 27  52.153660   5.371198                NaN      NL  Europe/Amsterdam  ...
# 28  51.984942   5.899548                NaN      NL  Europe/Amsterdam  ...
# 29  51.594459   4.776400                NaN      NL  Europe/Amsterdam  ...
# 30  51.807782   4.666821                NaN      NL  Europe/Amsterdam  ...
# 31  52.081000   4.308700                NaN      NL  Europe/Amsterdam  ...
# 32  52.080506   4.323991             8663.0      NL  Europe/Amsterdam  ...
# 33  51.443063   5.479950                NaN      NL  Europe/Amsterdam  ...
# 34  52.387110   4.636465                NaN      NL  Europe/Amsterdam  ...
# 35  50.849811   5.705875                NaN      NL  Europe/Amsterdam  ...
# 36  51.539859   4.456636                NaN      NL  Europe/Amsterdam  ...
# 37  51.925068   4.468839            23616.0      NL  Europe/Amsterdam  ...
# 38  52.308787   4.761487                NaN      NL  Europe/Amsterdam  ...
# 39  52.087580   5.111167            28938.0      NL  Europe/Amsterdam  ...
#
#       info:ja info:ko    info:pl     info:pt     info:ru    info:sv  \
# 0      アルクマール    알크마르        NaN         NaN     Алкмаар        NaN
# 1         NaN     NaN        NaN         NaN      Алмело        NaN
# 2     アムステルダム   암스테르담        NaN  Amesterdão   Амстердам        NaN
# 3     アペルドールン    아펠도른        NaN         NaN    Апелдорн        NaN
# 4       デルフト市     NaN        NaN         NaN       Делфт        NaN
# 5     デーフェンテル    데벤터르        NaN         NaN    Девентер        NaN
# 6         ゴーダ     하우다        NaN         NaN       Гауда        NaN
# 7     フローニンゲン    흐로닝언        NaN         NaN   Гронинген        NaN
# 8     デン・ヘルダー     NaN        NaN         NaN  Ден-Хелдер        NaN
# 9         NaN     NaN        NaN         NaN   Хилверсюм        NaN
# 10        NaN     NaN        NaN         NaN         NaN        NaN
# 11       ライデン     레이던      Lejda       Leida      Лейден        NaN
# 12        NaN     NaN        NaN         NaN         NaN        NaN
# 13     ナイメーヘン    네이메헌        NaN     Nimegue    Неймеген        NaN
# 14        NaN     NaN        NaN         NaN    Олдензал        NaN
# 15        NaN    시타르트        NaN         NaN     Ситтард        NaN
# 16     ティルブルフ    틸뷔르흐        NaN    Tilburgo     Тилбург        NaN
# 17        NaN     NaN        NaN         NaN         NaN        NaN
# 18        NaN     NaN        NaN         NaN        Весп        NaN
# 19        NaN     NaN        NaN         NaN   Винсхотен        NaN
# 20    アムステルダム   암스테르담        NaN  Amesterdão   Амстердам        NaN
# 21        NaN     NaN        NaN         NaN         NaN        NaN
# 22       ズヴォレ     즈볼러        NaN         NaN      Зволле        NaN
# 23     レーワルデン  레이우아르던        NaN         NaN   Леуварден        NaN
# 24     エンスヘーデ    엔스헤더        NaN         NaN     Энсхеде        NaN
# 25       アッセン      아선        NaN         NaN       Ассен        NaN
# 26    アムステルダム   암스테르담        NaN  Amesterdão   Амстердам        NaN
# 27        NaN     NaN        NaN         NaN   Амерсфорт        NaN
# 28       アーネム     아른험        NaN    Arnhemia       Арнем        NaN
# 29        ブレダ     브레다        NaN         NaN       Бреда        NaN
# 30     ドルトレヒト     NaN        NaN   Dordreque         NaN        NaN
# 31        NaN     NaN        NaN         NaN         NaN        NaN
# 32        ハーグ     헤이그       Haga      A Haia       Гаага        NaN
# 33  アイントホーフェン   에인트호번        NaN         NaN   Эйндховен        NaN
# 34      ハールレム     하를럼        NaN         NaN      Харлем        NaN
# 35    マーストリヒト  마스트리흐트        NaN   Mastrique   Маастрихт        NaN
# 36    ローゼンダール     로센달        NaN         NaN    Розендал        NaN
# 37     ロッテルダム    로테르담        NaN    Roterdão   Роттердам        NaN
# 38    アムステルダム   암스테르담  Amsterdam  Amesterdão   Амстердам  Amsterdam
# 39      ユトレヒト   위트레흐트        NaN     Utreque      Утрехт        NaN
#
#       info:tr  info:zh                    normalised_code  iata_airport_code
# 0         NaN    阿尔克马尔  urn:trainline:public:nloc:csv8607                NaN
# 1         NaN      NaN  urn:trainline:public:nloc:csv8608                NaN
# 2         NaN    阿姆斯特丹  urn:trainline:public:nloc:csv8609                NaN
# 3         NaN    阿珀尔多伦  urn:trainline:public:nloc:csv8610                NaN
# 4         NaN      NaN  urn:trainline:public:nloc:csv8615                NaN
# 5         NaN     代芬特尔  urn:trainline:public:nloc:csv8616                NaN
# 6         NaN       豪达  urn:trainline:public:nloc:csv8619                NaN
# 7         NaN     格罗宁根  urn:trainline:public:nloc:csv8620                NaN
# 8         NaN     登海尔德  urn:trainline:public:nloc:csv8621                NaN
# 9         NaN    希爾弗瑟姆  urn:trainline:public:nloc:csv8624                NaN
# 10        NaN      NaN  urn:trainline:public:nloc:csv8626                NaN
# 11        NaN       莱顿  urn:trainline:public:nloc:csv8627                NaN
# 12        NaN      NaN  urn:trainline:public:nloc:csv8630                NaN
# 13        NaN      奈梅亨  urn:trainline:public:nloc:csv8631                NaN
# 14        NaN      NaN  urn:trainline:public:nloc:csv8632                NaN
# 15        NaN      錫塔德  urn:trainline:public:nloc:csv8635                NaN
# 16        NaN      蒂尔堡  urn:trainline:public:nloc:csv8636                NaN
# 17        NaN      NaN  urn:trainline:public:nloc:csv8637                NaN
# 18        NaN      韋斯普  urn:trainline:public:nloc:csv8640                NaN
# 19        NaN     溫斯霍滕  urn:trainline:public:nloc:csv8641                NaN
# 20        NaN    阿姆斯特丹  urn:trainline:public:nloc:csv8643                NaN
# 21        NaN      NaN  urn:trainline:public:nloc:csv8644                NaN
# 22        NaN      兹沃勒  urn:trainline:public:nloc:csv8645                NaN
# 23        NaN      吕伐登  urn:trainline:public:nloc:csv8648                NaN
# 24        NaN     恩斯赫德  urn:trainline:public:nloc:csv8651                NaN
# 25        NaN       阿森  urn:trainline:public:nloc:csv8653                NaN
# 26        NaN    阿姆斯特丹  urn:trainline:public:nloc:csv8657                NaN
# 27        NaN      NaN  urn:trainline:public:nloc:csv8658                NaN
# 28        NaN      阿纳姆  urn:trainline:public:nloc:csv8659                NaN
# 29        NaN      布雷达  urn:trainline:public:nloc:csv8661                NaN
# 30        NaN      NaN  urn:trainline:public:nloc:csv8662                NaN
# 31        NaN      NaN  urn:trainline:public:nloc:csv8663                NaN
# 32      Lahey       海牙  urn:trainline:public:nloc:csv8664                NaN
# 33        NaN     埃因霍温  urn:trainline:public:nloc:csv8666                NaN
# 34        NaN      哈勒姆  urn:trainline:public:nloc:csv8667                NaN
# 35        NaN   马斯特里赫特  urn:trainline:public:nloc:csv8668                NaN
# 36        NaN     罗森达尔  urn:trainline:public:nloc:csv8669                NaN
# 37        NaN      鹿特丹  urn:trainline:public:nloc:csv8670                NaN
# 38  Amsterdam    阿姆斯特丹  urn:trainline:public:nloc:csv8672                AMS
# 39        NaN     乌得勒支  urn:trainline:public:nloc:csv8673                NaN
#
# [40 rows x 75 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c8e88e2e07d443b889961b3fc0c3e2a8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20950.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20550.0px%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c8e88e2e07d443b889961b3fc0c3e2a8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c8e88e2e07d443b889961b3fc0c3e2a8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c8e88e2e07d443b889961b3fc0c3e2a8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.155499%2C%205.38774%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# OLV Kerk Amersfoort coordinates
# `mymap = folium.Map(location = [52.155499, 5.387740],`
#
# Singapore (default coordinates from article)
# `mymap = folium.Map(location = [1.366623, 103.821285], `
